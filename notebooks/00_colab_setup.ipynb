# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
import os

os.system("mkdir -p ~/.ssh")
os.system("cp /content/drive/MyDrive/colab_ssh/id_ed25519 ~/.ssh/id_ed25519")
os.system("chmod 600 ~/.ssh/id_ed25519")
os.system("ssh-keyscan github.com >> ~/.ssh/known_hosts")

# %%
# !ssh -T git@github.com

# %%
# %cd /content/drive/MyDrive/cultural-verification-thesis

# %%
# !git pull

# %%
# !pip install -q \
transformers \
accelerate \
datasets \
pandas \
numpy \
tqdm \
huggingface_hub \
scikit-learn \
matplotlib

# %%
import torch

print("GPU available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %%
BASE_DIR = "/content/drive/MyDrive/cultural-verification-thesis"

DATA_DIR = f"{BASE_DIR}/data"
OUTPUT_DIR = f"{BASE_DIR}/outputs"
NOTEBOOK_DIR = f"{BASE_DIR}/notebooks"
TAXONOMY_DIR = f"{BASE_DIR}/taxonomy"

print("Project initialized.")
print(BASE_DIR)

# %%
import os

folders = [
    DATA_DIR,
    OUTPUT_DIR,
    NOTEBOOK_DIR,
    TAXONOMY_DIR
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Folders verified.")

# %%
print("=== ENVIRONMENT READY ===")

print(f"Base directory: {BASE_DIR}")

print("\nFolders:")
for folder in folders:
    print("-", folder)

print("\nGPU:")
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
